# %%
#### THIS NOTEBOOK TESTS SOME FUNCTIONALITY

# %%
# Importing standard modules and date-special modules
import pandas as pd
import numpy as np
from math import *

# %%
df_test = pd.read_csv('Test_Files/new_york_hotels.csv', encoding = 'cp1252')

# %%
def haversine(lat1, lon1, lat2, lon2):
    miles_constant = 3959
    lat1, lon1, lat2, lon2 = map(np.deg2rad, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1 
    dlon = lon2 - lon1 
    a = np.sin(dlat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2) ** 2
    c = 2 * np.arcsin(np.sqrt(a)) 
    mi = miles_constant * c
    return mi

# %%
# %%timeit
# Haversine applied on rows via iteration
haversine_series = []
for iter_index, iter_row in df_test.iterrows():
    haversine_series.append(haversine(40.671, -73.985, iter_row['latitude'], iter_row['longitude']))
df_test['distance'] = haversine_series
# Out:
# 146 ms ± 2.18 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit 
df_test['distance'] = df_test.apply(lambda iter_row: haversine(40.671, -73.985, iter_row['latitude'], iter_row['longitude']), axis = 1)
# Out:
# 47.3 ms ± 473 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit 
df_test['distance'] = haversine(40.671, -73.985, df_test['latitude'].values, df_test['longitude'].values)
# Out:
# 180 µs ± 1.36 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# Importing standard modules and date-special modules
import pandas as pd
import numpy as np
from math import *

# %%
coords = [('AA', 'one'), ('AA', 'six'), ('BB', 'one'), ('BB', 'two'), ('BB', 'six')]
index = pd.MultiIndex.from_tuples(coords)
df_test = pd.DataFrame([11, 22, 33, 44, 55], index, ['MyData'])
no_slice = slice(None)
df_test.loc[(no_slice, 'six'), :]
# Out:
#         MyData
# AA six      22
# BB six      55

# %%
import pandas as pd
import numpy as np

data = pd.concat([pd.DataFrame([['A']*72, list(pd.date_range('1/1/2011', periods=72, freq='H')), list(np.random.rand(72))], index = ['Group', 'Time', 'Value']).T,
                  pd.DataFrame([['B']*72, list(pd.date_range('1/1/2011', periods=72, freq='H')), list(np.random.rand(72))], index = ['Group', 'Time', 'Value']).T,
                  pd.DataFrame([['C']*72, list(pd.date_range('1/1/2011', periods=72, freq='H')), list(np.random.rand(72))], index = ['Group', 'Time', 'Value']).T],
                  axis = 0).set_index(['Group', 'Time'])

# %%
data
# Out:
#                                Value
# Group Time
# A     2011-01-01 00:00:00   0.274773
#       2011-01-01 01:00:00   0.786115
#       2011-01-01 02:00:00   0.908883
#       2011-01-01 03:00:00   0.520308
#       2011-01-01 04:00:00    0.62502
#       2011-01-01 05:00:00   0.386575
#       2011-01-01 06:00:00   0.316063
#       2011-01-01 07:00:00   0.135878
#       2011-01-01 08:00:00   0.912792
#       2011-01-01 09:00:00   0.165524
#       2011-01-01 10:00:00   0.478244
#       2011-01-01 11:00:00   0.550689
#       2011-01-01 12:00:00   0.652571
#       2011-01-01 13:00:00   0.260215
#       2011-01-01 14:00:00   0.369657
#       2011-01-01 15:00:00   0.804927
#       2011-01-01 16:00:00   0.416314
#       2011-01-01 17:00:00  0.0457923
#       2011-01-01 18:00:00  0.0876566
#       2011-01-01 19:00:00    0.83388
#       2011-01-01 20:00:00  0.0939612
#       2011-01-01 21:00:00   0.695269
#       2011-01-01 22:00:00   0.104417
#       2011-01-01 23:00:00   0.776025
# ...
